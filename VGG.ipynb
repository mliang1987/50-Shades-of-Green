# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import imageio
import numpy as np
import itertools
import json

import tensorflow as tf
import keras
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.applications import VGG16
from keras.layers import Dense, Input, GlobalAveragePooling2D, AveragePooling2D, Dropout, Flatten
from keras.models import Model
from keras.optimizers import SGD, Adam
from keras.utils import multi_gpu_model, to_categorical
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, CSVLogger

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

import cv2
from imutils import paths

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# dataset duplicate sanity check
base_dir = "/content/drive/My Drive/Deep Learning Project/"
test_dir = os.path.join(base_dir, "test")
train_dir = os.path.join(base_dir, "train")
overlaps = {}
for class_name in os.listdir(test_dir):
    train_imgs = os.listdir(os.path.join(train_dir, class_name))
    test_imgs = os.listdir(os.path.join(test_dir, class_name))
    print(class_name, len(train_imgs), len(test_imgs))
    overlaps[class_name] = []
    for i in test_imgs:
        if i in train_imgs:
            overlaps[class_name].append(i)
print("\noverlaps:")
for i in overlaps:
    print(i, len(overlaps[i]))
# Out:
# COVID-19 176 43
# NORMAL 176 43
# Viral Pneumonia 176 43
#
# overlaps:
# COVID-19 0
# NORMAL 0
# Viral Pneumonia 0

# %%
train_x = []
train_y = []
test_x = []
test_y = []

index = -1
for class_name in os.listdir(test_dir):
  train_imgs = list(paths.list_images(os.path.join(train_dir, class_name)))
  test_imgs = list(paths.list_images(os.path.join(test_dir, class_name)))
  index += 1

  for img in train_imgs:
    image = cv2.imread(img)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (256, 256))

    train_x.append(image)
    train_y.append(index)

  for img in test_imgs:
    image = cv2.imread(img)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (256, 256))

    test_x.append(image)
    test_y.append(index)

#COVID-19 = 0, Normal = 1, Viral Pneumonia = 2
print(len(train_x), len(train_y), train_y[0], train_y[176])
# Out:
# 528 528 0 1

# %%
train_x = np.array(train_x) / 255.0
train_y = np.array(train_y)

test_x = np.array(test_x) / 255.0
test_y = np.array(test_y)

train_y = to_categorical(train_y, num_classes = len(os.listdir(test_dir)))
test_y = to_categorical(test_y, num_classes = len(os.listdir(test_dir)))

val_split = 0.3
train_x, val_x, train_y, val_y = train_test_split(train_x, train_y, test_size = val_split, random_state = 42)

print(len(train_x), len(val_x))
# Out:
# 369 159

# %%
# Dataset config
input_shape = (256, 256, 3)
num_classes = 3
input_tensor = Input(shape = input_shape)

batch_size = 10 #40
max_epochs = 80 #60

#Optimizer
initial_lr = 1e-5 #1e-4
min_lr = 1e-6
lr_reduction_patience = 3
lr_change_factor = 0.2
early_stop_patience = 20
opt = Adam(learning_rate = initial_lr)

data_generator = ImageDataGenerator(
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
)

# %%
VGG_model = VGG16(include_top = False, input_tensor = input_tensor, weights = "imagenet")

x = VGG_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation = 'relu')(x)
predictions = Dense(3, activation = 'softmax')(x)

model = Model(inputs = VGG_model.input, outputs = predictions)

for i, layer in enumerate(VGG_model.layers):
    print(i, layer.name)
# Out:
# 0 input_1
# 1 block1_conv1
# 2 block1_conv2
# 3 block1_pool
# 4 block2_conv1
# 5 block2_conv2
# 6 block2_pool
# 7 block3_conv1
# 8 block3_conv2
# 9 block3_conv3
# 10 block3_pool
# 11 block4_conv1
# 12 block4_conv2
# 13 block4_conv3
# 14 block4_pool
# 15 block5_conv1
# 16 block5_conv2
# 17 block5_conv3
# 18 block5_pool

# %%
model.compile(optimizer=opt, loss="categorical_crossentropy", metrics=["accuracy"])

H = model.fit(
    data_generator.flow(train_x, train_y, batch_size = batch_size),
    validation_data=(val_x, val_y),
    epochs=max_epochs,
    verbose = 1)
# Out:
# Epoch 1/80
#  2/37 [>.............................] - ETA: 3s - loss: 1.1226 - accuracy: 0.4000WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0612s vs `on_train_batch_end` time: 0.1333s). Check your callbacks.
# 37/37 [==============================] - 13s 343ms/step - loss: 0.9771 - accuracy: 0.5854 - val_loss: 0.8679 - val_accuracy: 0.5660
# Epoch 2/80
# 37/37 [==============================] - 9s 236ms/step - loss: 0.6498 - accuracy: 0.7615 - val_loss: 0.5302 - val_accuracy: 0.7233
# Epoch 3/80
# 37/37 [==============================] - 9s 238ms/step - loss: 0.5028 - accuracy: 0.7967 - val_loss: 0.3784 - val_accuracy: 0.8616
# Epoch 4/80
# 37/37 [==============================] - 9s 238ms/step - loss: 0.3483 - accuracy: 0.8753 - val_loss: 0.3386 - val_accuracy: 0.8994
# Epoch 5/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.2772 - accuracy: 0.9133 - val_loss: 0.2464 - val_accuracy: 0.9057
# Epoch 6/80
# 37/37 [==============================] - 9s 239ms/step - loss: 0.2987 - accuracy: 0.9079 - val_loss: 0.2330 - val_accuracy: 0.9119
# Epoch 7/80
# 37/37 [==============================] - 9s 243ms/step - loss: 0.2422 - accuracy: 0.9106 - val_loss: 0.2202 - val_accuracy: 0.9497
# Epoch 8/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.2644 - accuracy: 0.8997 - val_loss: 0.2138 - val_accuracy: 0.9560
# Epoch 9/80
# 37/37 [==============================] - 9s 244ms/step - loss: 0.2314 - accuracy: 0.9187 - val_loss: 0.2946 - val_accuracy: 0.8616
# Epoch 10/80
# 37/37 [==============================] - 9s 243ms/step - loss: 0.2298 - accuracy: 0.9295 - val_loss: 0.2410 - val_accuracy: 0.9245
# Epoch 11/80
# 37/37 [==============================] - 9s 243ms/step - loss: 0.2183 - accuracy: 0.9268 - val_loss: 0.3235 - val_accuracy: 0.8679
# Epoch 12/80
# 37/37 [==============================] - 9s 240ms/step - loss: 0.2126 - accuracy: 0.9241 - val_loss: 0.2190 - val_accuracy: 0.9560
# Epoch 13/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.1926 - accuracy: 0.9322 - val_loss: 0.1678 - val_accuracy: 0.9434
# Epoch 14/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.1904 - accuracy: 0.9350 - val_loss: 0.1572 - val_accuracy: 0.9434
# Epoch 15/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.1719 - accuracy: 0.9485 - val_loss: 0.2900 - val_accuracy: 0.8994
# Epoch 16/80
# 37/37 [==============================] - 9s 243ms/step - loss: 0.1598 - accuracy: 0.9485 - val_loss: 0.6166 - val_accuracy: 0.7421
# Epoch 17/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.2292 - accuracy: 0.9024 - val_loss: 0.2374 - val_accuracy: 0.8931
# Epoch 18/80
# 37/37 [==============================] - 9s 243ms/step - loss: 0.1748 - accuracy: 0.9431 - val_loss: 0.1647 - val_accuracy: 0.9497
# Epoch 19/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.1406 - accuracy: 0.9539 - val_loss: 0.1668 - val_accuracy: 0.9245
# Epoch 20/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.1361 - accuracy: 0.9566 - val_loss: 0.2069 - val_accuracy: 0.9119
# Epoch 21/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.1443 - accuracy: 0.9458 - val_loss: 0.1594 - val_accuracy: 0.9371
# Epoch 22/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.1439 - accuracy: 0.9431 - val_loss: 0.1444 - val_accuracy: 0.9560
# Epoch 23/80
# 37/37 [==============================] - 9s 240ms/step - loss: 0.1298 - accuracy: 0.9458 - val_loss: 0.3499 - val_accuracy: 0.8553
# Epoch 24/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.1625 - accuracy: 0.9377 - val_loss: 0.1831 - val_accuracy: 0.9182
# Epoch 25/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.1420 - accuracy: 0.9431 - val_loss: 0.2095 - val_accuracy: 0.9119
# Epoch 26/80
# 37/37 [==============================] - 9s 240ms/step - loss: 0.1177 - accuracy: 0.9539 - val_loss: 0.1269 - val_accuracy: 0.9686
# Epoch 27/80
# 37/37 [==============================] - 9s 240ms/step - loss: 0.1326 - accuracy: 0.9539 - val_loss: 0.2574 - val_accuracy: 0.8805
# Epoch 28/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.1366 - accuracy: 0.9539 - val_loss: 0.1382 - val_accuracy: 0.9434
# Epoch 29/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.1090 - accuracy: 0.9593 - val_loss: 0.2316 - val_accuracy: 0.9245
# Epoch 30/80
# 37/37 [==============================] - 9s 243ms/step - loss: 0.1089 - accuracy: 0.9593 - val_loss: 0.1709 - val_accuracy: 0.9245
# Epoch 31/80
# 37/37 [==============================] - 9s 240ms/step - loss: 0.1310 - accuracy: 0.9377 - val_loss: 0.1265 - val_accuracy: 0.9560
# Epoch 32/80
# 37/37 [==============================] - 9s 240ms/step - loss: 0.1338 - accuracy: 0.9431 - val_loss: 0.2150 - val_accuracy: 0.9119
# Epoch 33/80
# 37/37 [==============================] - 9s 240ms/step - loss: 0.0689 - accuracy: 0.9810 - val_loss: 0.1595 - val_accuracy: 0.9371
# Epoch 34/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.1074 - accuracy: 0.9485 - val_loss: 0.1291 - val_accuracy: 0.9560
# Epoch 35/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.0870 - accuracy: 0.9675 - val_loss: 0.1934 - val_accuracy: 0.9245
# Epoch 36/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0629 - accuracy: 0.9783 - val_loss: 0.1831 - val_accuracy: 0.9308
# Epoch 37/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0829 - accuracy: 0.9593 - val_loss: 0.1469 - val_accuracy: 0.9371
# Epoch 38/80
# 37/37 [==============================] - 9s 243ms/step - loss: 0.0923 - accuracy: 0.9702 - val_loss: 0.3965 - val_accuracy: 0.8742
# Epoch 39/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0943 - accuracy: 0.9729 - val_loss: 0.2673 - val_accuracy: 0.9119
# Epoch 40/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0862 - accuracy: 0.9729 - val_loss: 0.1154 - val_accuracy: 0.9560
# Epoch 41/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.0677 - accuracy: 0.9783 - val_loss: 0.2981 - val_accuracy: 0.9182
# Epoch 42/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0599 - accuracy: 0.9756 - val_loss: 0.2202 - val_accuracy: 0.9371
# Epoch 43/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0994 - accuracy: 0.9675 - val_loss: 0.1297 - val_accuracy: 0.9560
# Epoch 44/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.0408 - accuracy: 0.9892 - val_loss: 0.1625 - val_accuracy: 0.9434
# Epoch 45/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.1550 - accuracy: 0.9539 - val_loss: 0.2010 - val_accuracy: 0.9371
# Epoch 46/80
# 37/37 [==============================] - 9s 240ms/step - loss: 0.0531 - accuracy: 0.9837 - val_loss: 0.1463 - val_accuracy: 0.9371
# Epoch 47/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.0841 - accuracy: 0.9756 - val_loss: 0.1740 - val_accuracy: 0.9371
# Epoch 48/80
# 37/37 [==============================] - 9s 244ms/step - loss: 0.0330 - accuracy: 0.9892 - val_loss: 0.1318 - val_accuracy: 0.9434
# Epoch 49/80
# 37/37 [==============================] - 9s 244ms/step - loss: 0.0396 - accuracy: 0.9919 - val_loss: 0.1304 - val_accuracy: 0.9497
# Epoch 50/80
# 37/37 [==============================] - 9s 243ms/step - loss: 0.0392 - accuracy: 0.9919 - val_loss: 0.1638 - val_accuracy: 0.9245
# Epoch 51/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.0453 - accuracy: 0.9864 - val_loss: 0.1728 - val_accuracy: 0.9308
# Epoch 52/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.0433 - accuracy: 0.9892 - val_loss: 0.1207 - val_accuracy: 0.9686
# Epoch 53/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0661 - accuracy: 0.9702 - val_loss: 0.1268 - val_accuracy: 0.9434
# Epoch 54/80
# 37/37 [==============================] - 9s 243ms/step - loss: 0.0338 - accuracy: 0.9892 - val_loss: 0.1548 - val_accuracy: 0.9497
# Epoch 55/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0551 - accuracy: 0.9783 - val_loss: 0.1816 - val_accuracy: 0.9308
# Epoch 56/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.0418 - accuracy: 0.9837 - val_loss: 0.1431 - val_accuracy: 0.9434
# Epoch 57/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.0181 - accuracy: 0.9973 - val_loss: 0.2056 - val_accuracy: 0.9245
# Epoch 58/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0274 - accuracy: 0.9946 - val_loss: 0.1548 - val_accuracy: 0.9497
# Epoch 59/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.4934 - val_accuracy: 0.8742
# Epoch 60/80
# 37/37 [==============================] - 9s 240ms/step - loss: 0.0166 - accuracy: 0.9892 - val_loss: 0.2094 - val_accuracy: 0.9308
# Epoch 61/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0433 - accuracy: 0.9864 - val_loss: 0.1524 - val_accuracy: 0.9497
# Epoch 62/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0569 - accuracy: 0.9864 - val_loss: 0.2102 - val_accuracy: 0.9182
# Epoch 63/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0426 - accuracy: 0.9864 - val_loss: 0.1421 - val_accuracy: 0.9560
# Epoch 64/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0698 - accuracy: 0.9729 - val_loss: 0.4947 - val_accuracy: 0.8742
# Epoch 65/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0300 - accuracy: 0.9946 - val_loss: 0.4995 - val_accuracy: 0.8679
# Epoch 66/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.0516 - accuracy: 0.9810 - val_loss: 0.4048 - val_accuracy: 0.8805
# Epoch 67/80
# 37/37 [==============================] - 9s 243ms/step - loss: 0.0914 - accuracy: 0.9702 - val_loss: 0.1069 - val_accuracy: 0.9748
# Epoch 68/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0410 - accuracy: 0.9837 - val_loss: 0.1183 - val_accuracy: 0.9623
# Epoch 69/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.0372 - accuracy: 0.9837 - val_loss: 0.1914 - val_accuracy: 0.9245
# Epoch 70/80
# 37/37 [==============================] - 9s 240ms/step - loss: 0.0194 - accuracy: 0.9919 - val_loss: 0.2470 - val_accuracy: 0.9182
# Epoch 71/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.0220 - accuracy: 0.9946 - val_loss: 0.3350 - val_accuracy: 0.9182
# Epoch 72/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0217 - accuracy: 0.9919 - val_loss: 0.2790 - val_accuracy: 0.9119
# Epoch 73/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.1690 - val_accuracy: 0.9371
# Epoch 74/80
# 37/37 [==============================] - 9s 243ms/step - loss: 0.0288 - accuracy: 0.9919 - val_loss: 0.1527 - val_accuracy: 0.9560
# Epoch 75/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.0619 - accuracy: 0.9756 - val_loss: 0.1454 - val_accuracy: 0.9497
# Epoch 76/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.0234 - accuracy: 0.9919 - val_loss: 0.5863 - val_accuracy: 0.8679
# Epoch 77/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0232 - accuracy: 0.9892 - val_loss: 0.4844 - val_accuracy: 0.8805
# Epoch 78/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.0137 - accuracy: 0.9946 - val_loss: 0.1740 - val_accuracy: 0.9371
# Epoch 79/80
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0171 - accuracy: 0.9973 - val_loss: 0.1779 - val_accuracy: 0.9371
# Epoch 80/80
# 37/37 [==============================] - 9s 241ms/step - loss: 0.1542 - accuracy: 0.9295 - val_loss: 0.1947 - val_accuracy: 0.9245

# %%
preds = model.predict(test_x, batch_size = batch_size)
preds = np.argmax(preds, axis=1)

# %%
# Source: Scikit Learn website
# http://scikit-learn.org/stable/auto_examples/
# model_selection/plot_confusion_matrix.html#sphx-glr-auto-examples-model-
# selection-plot-confusion-matrix-py


def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    
    # set the size of the figure here
    plt.figure(figsize=(15,10))

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=80) # set x-axis text angle here
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
cm = confusion_matrix(test_y.argmax(axis=1), preds)

cm_plot_labels = os.listdir(test_dir)
plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix')

accuracy = np.sum(np.diag(cm)) / np.sum(cm)
print("Accuracy: ", accuracy)
# Out:
# Confusion matrix, without normalization
# [[43  0  0]
#  [ 0 41  2]
#  [ 0  5 38]]
# Accuracy:  0.9457364341085271

# %%
report =  classification_report(test_y.argmax(axis=1), preds, target_names=cm_plot_labels)

print(report)
# Out:
#                  precision    recall  f1-score   support
#
#        COVID-19       1.00      1.00      1.00        43
#          NORMAL       0.89      0.95      0.92        43
# Viral Pneumonia       0.95      0.88      0.92        43
#
#        accuracy                           0.95       129
#       macro avg       0.95      0.95      0.95       129
#    weighted avg       0.95      0.95      0.95       129

# %%
# display the loss and accuracy curves

acc = H.history['accuracy']
val_acc = H.history['val_accuracy']
loss = H.history['loss']
val_loss = H.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.figure()

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
